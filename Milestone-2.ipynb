# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# Part-A: Setup

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
df = pd.read_csv('Global_Tech_Gadget_Consumption.csv')
df.head()
# Out:
#   Country  Year  Smartphone Sales (Millions)  Laptop Shipments (Millions)  \
# 0     USA  2015                       111.37                       123.63
# 1     USA  2016                       224.65                        65.27
# 2     USA  2017                       102.12                        26.75
# 3     USA  2018                       148.10                       129.28
# 4     USA  2019                        83.93                        97.81
#
#    Gaming Console Adoption (%)  Smartwatch Penetration (%)  \
# 0                        12.05                       14.49
# 1                        12.92                        9.88
# 2                        19.63                       17.35
# 3                        26.44                       12.45
# 4                        20.84                        6.18
#
#    Average Consumer Spending on Gadgets ($)  E-Waste Generated (Metric Tons)  \
# 0                                    311.21                           939.89
# 1                                    250.46                          1361.42
# 2                                   2404.22                           872.52
# 3                                   1883.37                          1241.41
# 4                                    777.42                          1939.39
#
#    5G Penetration Rate (%)
# 0                    54.64
# 1                    53.61
# 2                    29.94
# 3                    75.88
# 4                    76.26

# %%
print("Dataset size:", df.shape)
# Out:
# Dataset size: (110, 9)

# %% [markdown]
# Part-B: Simple Random Sampling

# %%
sample_size = 50
srs = df.sample(n=sample_size, random_state=42)
print(srs.head())
print("Population mean:", df['Smartphone Sales (Millions)'].mean())
print("Sample mean:", srs['Smartphone Sales (Millions)'].mean())
# Out:
#         Country  Year  Smartphone Sales (Millions)  \
# 78  South Korea  2016                       111.02
# 10          USA  2025                       367.74
# 4           USA  2019                        83.93
# 84  South Korea  2022                       444.60
# 64       France  2024                       234.44
#
#     Laptop Shipments (Millions)  Gaming Console Adoption (%)  \
# 78                        21.29                        16.48
# 10                        78.09                        35.38
# 4                         97.81                        20.84
# 84                        80.76                        35.63
# 64                       140.20                        16.26
#
#     Smartwatch Penetration (%)  Average Consumer Spending on Gadgets ($)  \
# 78                        6.36                                   1872.46
# 10                       19.68                                   2611.60
# 4                         6.18                                    777.42
# 84                        2.64                                   2891.90
# 64                        8.07                                    755.94
#
#     E-Waste Generated (Metric Tons)  5G Penetration Rate (%)
# 78                           111.47                    62.47
# 10                           923.74                    33.02
# 4                           1939.39                    76.26
# 84                           142.36                    55.94
# 64                          1270.77                    47.55
# Population mean: 269.0955454545454
# Sample mean: 268.22799999999995

# %% [markdown]
# Part-C: Systematic Sampling

# %%
n = 50
k = len(df) // n
start = np.random.randint(0, k)
sys_sample = df.iloc[start::k][:n]
sys_sample.head()
# Out:
#   Country  Year  Smartphone Sales (Millions)  Laptop Shipments (Millions)  \
# 1     USA  2016                       224.65                        65.27
# 3     USA  2018                       148.10                       129.28
# 5     USA  2020                       300.49                       100.59
# 7     USA  2022                       239.21                        63.46
# 9     USA  2024                       444.57                        58.60
#
#    Gaming Console Adoption (%)  Smartwatch Penetration (%)  \
# 1                        12.92                        9.88
# 3                        26.44                       12.45
# 5                        28.16                       17.68
# 7                         7.04                       14.72
# 9                         7.67                       15.42
#
#    Average Consumer Spending on Gadgets ($)  E-Waste Generated (Metric Tons)  \
# 1                                    250.46                          1361.42
# 3                                   1883.37                          1241.41
# 5                                    593.73                           136.97
# 7                                    339.59                           175.00
# 9                                   1107.74                          1902.16
#
#    5G Penetration Rate (%)
# 1                    53.61
# 3                    75.88
# 5                    58.45
# 7                    65.69
# 9                    55.95

# %% [markdown]
# Part-D: Stratified Sampling

# %%
strata_col = "Gaming Console Adoption (%)"  # your column
sample_size = 50

# proportional fraction for each group
frac = sample_size / len(df)

# stratified sample
stratified_sample = df.groupby(strata_col, group_keys=False).sample(frac=frac, random_state=42)

stratified_sample.head()
# Out:
#         Country  Year  Smartphone Sales (Millions)  \
# 78  South Korea  2016                       111.02
# 77  South Korea  2015                       241.26
# 73        Japan  2022                       238.54
# 84  South Korea  2022                       444.60
#
#     Laptop Shipments (Millions)  Gaming Console Adoption (%)  \
# 78                        21.29                        16.48
# 77                       116.14                        19.64
# 73                        72.65                        28.46
# 84                        80.76                        35.63
#
#     Smartwatch Penetration (%)  Average Consumer Spending on Gadgets ($)  \
# 78                        6.36                                   1872.46
# 77                       21.05                                    470.41
# 73                        8.33                                    458.93
# 84                        2.64                                   2891.90
#
#     E-Waste Generated (Metric Tons)  5G Penetration Rate (%)
# 78                           111.47                    62.47
# 77                           147.73                    21.34
# 73                          1118.76                    58.11
# 84                           142.36                    55.94

# %% [markdown]
# Part-E: Cluster Sampling

# %%
df['cluster_id'] = df.index // (len(df)//10)  # 10 clusters
selected_clusters = np.random.choice(df['cluster_id'].unique(), size=2, replace=False)
cluster_sample = df[df['cluster_id'].isin(selected_clusters)]
print("Selected clusters:", selected_clusters)
cluster_sample.head()
# Out:
# Selected clusters: [1 9]
#    Country  Year  Smartphone Sales (Millions)  Laptop Shipments (Millions)  \
# 11   China  2015                        77.62                        87.58
# 12   China  2016                        93.38                       137.35
# 13   China  2017                       499.89                        99.05
# 14   China  2018                       478.75                        45.72
# 15   China  2019                       254.10                       130.87
#
#     Gaming Console Adoption (%)  Smartwatch Penetration (%)  \
# 11                        18.77                       10.89
# 12                        21.03                       23.74
# 13                        22.01                        5.32
# 14                        35.63                        2.04
# 15                        16.48                       19.44
#
#     Average Consumer Spending on Gadgets ($)  E-Waste Generated (Metric Tons)  \
# 11                                   2018.37                          1187.13
# 12                                   1655.00                           563.90
# 13                                   1465.64                          1037.50
# 14                                   2653.45                          1325.48
# 15                                   1491.33                          1825.14
#
#     5G Penetration Rate (%)  cluster_id
# 11                    28.59           1
# 12                    26.13           1
# 13                    12.43           1
# 14                    58.19           1
# 15                    13.12           1
