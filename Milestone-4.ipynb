# %% [markdown]
# # Milestone 4 - STA 2101: Measures of Central Tendency and Dispersion
# Department of Electrical and Electronic Engineering,ULAB

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('Global_Tech_Gadget_Consumption.csv')
df.head()
# Out:
#   Country  Year  Smartphone Sales (Millions)  Laptop Shipments (Millions)  \
# 0     USA  2015                       111.37                       123.63
# 1     USA  2016                       224.65                        65.27
# 2     USA  2017                       102.12                        26.75
# 3     USA  2018                       148.10                       129.28
# 4     USA  2019                        83.93                        97.81
#
#    Gaming Console Adoption (%)  Smartwatch Penetration (%)  \
# 0                        12.05                       14.49
# 1                        12.92                        9.88
# 2                        19.63                       17.35
# 3                        26.44                       12.45
# 4                        20.84                        6.18
#
#    Average Consumer Spending on Gadgets ($)  E-Waste Generated (Metric Tons)  \
# 0                                    311.21                           939.89
# ...

# %% [markdown]
# ## Task 1: Measures of Central Tendency

# %%
num_cols = ['Gaming Console Adoption (%)' ,	'Smartwatch Penetration (%)']

for col in num_cols:
    print(f'\nColumn: {col}')
    mean_val = df[col].mean()
    median_val = df[col].median()
    mode_val = df[col].mode().tolist()
    print(f'Mean: {mean_val}')
    print(f'Median: {median_val}')
    print(f'Mode: {mode_val}')
# Out:
# Column: Gaming Console Adoption (%)
# Mean: 21.753545454545453
# Median: 20.365000000000002
# Mode: [16.48, 19.64, 28.46, 35.63]
#
# Column: Smartwatch Penetration (%)
# Mean: 14.129818181818182
# Median: 14.52
# Mode: [7.1, 12.47]

# %% [markdown]
# ## Task 2: Measures of Dispersion

# %%
for col in num_cols:
    print(f'\nColumn: {col}')
    variance_val = df[col].var()
    std_dev_val = df[col].std()
    print(f'Variance: {variance_val}')
    print(f'Standard Deviation: {std_dev_val}')
# Out:
# Column: Gaming Console Adoption (%)
# Variance: 95.03436254378647
# Standard Deviation: 9.748556946737628
#
# Column: Smartwatch Penetration (%)
# Variance: 40.363021984987476
# Standard Deviation: 6.353189906258704

# %% [markdown]
# ## Task 3: Visualization

# %%
for col in num_cols:
    plt.figure(figsize=(8,5))
    sns.histplot(df[col], bins=10, kde=False, color='skyblue', edgecolor='black')
    plt.axvline(df[col].mean(), color='red', linestyle='dashed', linewidth=1.5, label='Mean')
    plt.axvline(df[col].median(), color='green', linestyle='dashed', linewidth=1.5, label='Median')
    plt.axvline(df[col].mode()[0], color='orange', linestyle='dashed', linewidth=1.5, label='Mode')
    plt.title(f'Histogram of {col}')
    plt.xlabel(col)
    plt.ylabel('Frequency')
    plt.legend()
    plt.show()

# %% [markdown]
# ## Task 4: Analysis and Conclusion
# It is observed that the histogram of "Gaming Console Adoption (%)" has multiple peaks visually.The shape appears to be unstable,so the type is not uniform.Standard deviation indicates that the datapoints are widely spread out.Therefore the histogram type can be classified as multimodal or more specifically,trimodal.
#
# It is also observed that despite the histogram of "Smartwatch Penetration (%)" having a stable shape indicating this to be similar to being uniform,two distinct peaks have been detected.Standard deviation indicates that the datapoints are widely spread out.This indicates that the histogram type is bimodal.
